# %% [markdown]
# # Final Project FP-3:  Descriptive Statistics (Example)
#
#
# <br>
# <br>

# %% [markdown]
# ___
#
# # <span style="color:blue">Impact of Air Pollution on Public Health</span>
#
#
# ### Overview:
#
# * **Name**:  <span style="color:blue">Yaroslava Tokarieva</span>
# * **Student number**:  <span style="color:blue">B990377233</span>
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * The purpose of this Final Project is to investigate how air pollution levels are associated with health outcomes across countries and NUTS regions.
# * The key **dependent variables (DVs)** are:
#     * `Value` -represents the estimated health impact associated with exposure to a specific air pollutant for a given population group.
#     * `Value for 100k Of Affected Population`
# * Key **independent variables (IVs)** include:
#     * `Air Pollution Average [ug/m3]`
#     * `Air Pollution Population Weighted Average [ug/m3]`
#     * `Air Pollutant`
#     * `Degree Of Urbanisation`
#     * `Population`
#     * `Affected Population`
#     * `Populated Area [km2]`
#     * `Year`
#     * `Sex`
#     * `Description Of Age Group`
#     * `Category`
#     * `Outcome`
#     * `Health Indicator`
# * This dataset contains observations across multiple European countries and NUTS regions.
#   Each row corresponds to one population group defined by region, demographic characteristics, and pollutant exposure.

# %% [markdown]
# ### Dataset source:
#
# The data come from the **“Burden of disease of air pollution (Countries & NUTS)”** dataset, provided by the
# [European Environment Agency (EEA)](https://www.eea.europa.eu/en).
#
# The data are available for download **[here](https://discomap.eea.europa.eu/App/AQViewer/index.html?fqn=Airquality_Dissem.ebd.countries_and_nuts&ScenarioDescription=Baseline%20from%20WHO%202021%20AQG&UrbanisationDegree=All%20Areas%20(incl.unclassified)&Year=2022&Sex=Total)**.
#
# Published: **10 Dec 2024** by the **European Environment Agency**.
#
# #### References:
#
# European Environment Agency (2024). *Burden of disease of air pollution (Countries & NUTS)*.

# %% [markdown]
# ___
#
# ## Descriptive Statistics

# %%
import sys
import os

# Додаємо шлях до модуля
sys.path.append(os.path.abspath("src"))

# Імпортуємо модулі
from parse_data import get_clean_data
from descriptive import (
    central_tendency_table,
    dispersion_table,
    plot_descriptive
)

# Завантажуємо дані
df = get_clean_data("DataExtract.csv")

df.head()
# Out:
#    value  value_per_100k  year  pollution_avg  pollution_pop_avg pollutant  \
# 0    103              76  2022         5567.3             5335.0        O3
# 1      6               5  2022            9.1               10.0     PM2.5
# 2     66              64  2022            9.1               10.0     PM2.5
# 3    179             174  2022            9.1               10.0     PM2.5
# 4     14              14  2022           10.7               14.9       NO2
#
#    population  affected_pop  area_km2                   urban_degree    sex  \
# 0      135801        135800     320.3  All Areas (incl.unclassified)  Total
# 1      135801        103242     320.3  All Areas (incl.unclassified)  Total
# 2      135801        103242     320.3  All Areas (incl.unclassified)  Total
# 3      135801        103242     320.3  All Areas (incl.unclassified)  Total
# 4      117583        101186     220.9  All Areas (incl.unclassified)  Total
#
#             age_group                 category  \
# ...

# %%
central_tendency_table(df)
# Out:
# === CENTRAL TENDENCY ===
#              value  value_per_100k    year  pollution_avg  pollution_pop_avg  \
# mean    1026.02323       64.465895  2022.0     264.184692         236.566906
# median    47.00000       19.000000  2022.0       9.100000          11.500000
# mode       0.00000        0.000000  2022.0       8.500000           8.700000
#
#           population  affected_pop     area_km2
# mean    2.047130e+06  1.445786e+06  9008.954033
# median  3.563360e+05  2.465810e+05  1347.600000
# mode    3.369500e+04  2.611500e+04     2.000000
#              value  value_per_100k    year  pollution_avg  pollution_pop_avg  \
# mean    1026.02323       64.465895  2022.0     264.184692         236.566906
# median    47.00000       19.000000  2022.0       9.100000          11.500000
# mode       0.00000        0.000000  2022.0       8.500000           8.700000
#
#           population  affected_pop     area_km2
# mean    2.047130e+06  1.445786e+06  9008.954033
# ...

# %%
dispersion_table(df)
# Out:
# === DISPERSION ===
#                value  value_per_100k    year  pollution_avg  \
# st.dev  1.988432e+04      152.150105     0.0    1199.605569
# min     0.000000e+00        0.000000  2022.0       0.100000
# max     2.643630e+06     3728.000000  2022.0   13840.400000
# range   2.643630e+06     3728.000000     0.0   13840.300000
# 25th    7.000000e+00        3.000000  2022.0       7.400000
# 75th    2.330000e+02       64.000000  2022.0      12.400000
# IQR     2.260000e+02       61.000000     0.0       5.000000
#
#         pollution_pop_avg    population  affected_pop      area_km2
# st.dev         1052.87051  2.061781e+07  1.509331e+07  9.049491e+04
# min               0.30000  1.782300e+04  2.674000e+03  2.000000e+00
# max           11702.40000  5.582807e+08  5.582716e+08  2.687568e+06
# range         11702.10000  5.582628e+08  5.582689e+08  2.687566e+06
# 25th              9.00000  1.654100e+05  1.107740e+05  5.714000e+02
# ...

# %% [markdown]
# DALY (Disability-Adjusted Life Year) is a measure that represents one year of healthy life lost due to illness, disability, or premature death.
# It combines years of life lost and years lived with disability into a single number that reflects the total health burden.

# %%
plot_descriptive(df)

# %% [markdown]
# ## Hypothesis Testing Results
#
# ---
#
# ### **General Relationship Between PM2.5 and DALY**
#
# Before testing specific hypotheses, I checked whether PM2.5 and DALY are related in general.
# Across the whole dataset, the correlation between PM2.5 and DALY per 100k is very strong and positive.
# This means that higher pollution levels are consistently linked to higher health burden.
#
# This overall pattern gives a good starting point for the more detailed subgroup analyses below.
#
# ---
#
# ### **Hypothesis 1 — Age changes how strongly PM2.5 affects DALY**
#
# **Idea:**
# Older people might be more affected by PM2.5 than younger people.
#
# **Result:**
# This hypothesis is supported.
# Children (<15) show the weakest increase in DALY when PM2.5 rises.
# Adults have a stronger increase, and older adults (50+) have the steepest rise.
#
# In other words, **PM2.5 affects everyone, but especially older age groups**.
# The figure below shows these different slopes for each age category.
#
# ---
#
# ### **Hypothesis 2 — Different diseases respond differently to PM2.5**
#
# **Idea:**
# Not all diseases should react to air pollution in the same way.
#
# **Result:**
# This hypothesis is also supported.
# Lung cancer has the strongest PM2.5 sensitivity (the highest slope).
# Asthma and COPD show smaller, but still positive, increases in DALY as pollution rises.
#
# So **some diseases are much more strongly linked to PM2.5 than others**, and this helps explain the overall health burden.
#
# ---
#
# The two figures below illustrate these main findings.

# %%
from classical import prepare_analysis_data, run_statistical_tests, plot_environmental_impact

df1 = prepare_analysis_data("DataExtract.csv")
run_statistical_tests(df1)
plot_environmental_impact(df1)
# Out:
# Data shape after filtering: (9439, 18)
#
# TEST 1 — Disease-specific PM2.5 sensitivity
# Lung cancer: n=1589, slope=22.0814 (Δ DALY/100k per 1 µg/m³ PM2.5)
# Chronic obstructive pulmonary disease: n=1588, slope=10.7586 (Δ DALY/100k per 1 µg/m³ PM2.5)
# Asthma: n=1587, slope=11.0577 (Δ DALY/100k per 1 µg/m³ PM2.5)
#
# TEST 2 — PM2.5
# ANOVA F = 648.753886801797
# ANOVA p = 0.0
# Spearman trend rho = 0.9999999999999999
# p = 6.646897422032013e-64
#
# TEST 3 — Age × PM2.5 interaction
# Interaction Spearman rho = 0.852902390550883
# p = 0.0

# %% [markdown]
# # Machine Learning Analysis
#
# In this section, we present the results of our machine learning analysis. We start with the model validation to establish its reliability, followed by an analysis of the features that drive these predictions.
#
# ---
#
# ## 1. Model Validation
#
# To evaluate whether the machine learning approach is reliable, we first compare the model's predictions against the actual observed data.
#
#
#
# **Figure 1: Model Validation - Predicted vs. Actual DALYs**
#
# **What the plot shows:** - X-axis: Actual DALYs (Disability-Adjusted Life Years per 100,000 population).
# - Y-axis: Predicted values from the **Random Forest** model.
#
# **Key metrics:** - **R² = 0.703**: The model explains 70.3% of the variance in the data. This is a high value for medical-environmental data, indicating strong predictive performance.
# - **Regression line:** The **red line in Figure 1** represents the ideal trend. Most blue points are close to this line, showing that the model performs reliably.
# - **Dispersion:** Predictions are very accurate for low DALY values. For high values (>400), the spread increases, which is normal for complex socio-medical indicators.
#
# **Insight:** The model captures the main trends in the data and helps identify critical DALY levels for further analysis or interventions.
#
# **Why I chose this plot:** This plot was selected as one of the main results because it clearly demonstrates **the predictive power and accuracy of the model**, which is crucial for evaluating whether the machine learning approach is reliable. It also allows the reader to visually assess the model's performance across the full range of DALY values.
#
# ---
#
# ## 2. Feature Importance
#
# After validating the model's performance in Figure 1, we analyze which factors the model considers most important for making these predictions.
#
#
#
# **Figure 2: Feature Importance Distribution**
#
# **What the plot shows:** - Explains which factors the model considers most important for predicting DALYs.
#
# **Importance distribution:** 1. **Pollution Level** — ~60% weight. The most important factor, confirming the role of PM2.5 in overall disease burden.
# 2. **Disease Type** — ~39% weight. The type of disease significantly affects DALYs, especially in interaction with pollution.
# 3. **Age Group** — <1% weight. Despite its medical relevance, age has minimal influence in this analysis.
#
# **Insight:** Although age is medically important, in macro-analysis of disease burden from PM2.5, the pollution level itself is the dominant predictor, highlighting its priority in public health policy.
#
# **Why I chose this plot:** This plot was selected because it provides **a clear insight into the factors driving the model's predictions**, allowing the reader to understand which variables are most influential. It complements the Model Validation plot (Figure 1) by explaining **why the model makes the predictions it does**, which is key for an insightful analysis.

# %%
import machine as ml  
import numpy as np

X_train, X_test, y_train, y_test = ml.prepare_ml_data(df)

model, cv_scores, y_pred = ml.run_validated_model(X_train, y_train, X_test, y_test)

ml.plot_validation_results(y_test, y_pred, fig_num=1)
ml.plot_feature_importance(model, fig_num=2)


print(f"Mean Cross-Validation Score: {cv_scores.mean():.4f}")
# Out:
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# Mean Cross-Validation Score: 0.6468

# %% [markdown]
# # Comparison
#
# ---
#
# ## 1. Improved Model Validation
#
# To evaluate the impact of preprocessing, we re-validated the **Random Forest** model using scaled features. This allows us to assess the model's reliability on a normalized dataset.
#
#
#
# **Figure 1: Improved Model Validation (Scaled Features)**
#
# **What the plot shows:** - **X-axis:** Actual DALYs (Disability-Adjusted Life Years per 100,000 population).
# - **Y-axis:** Predicted values from the improved Random Forest model.
# - **Regression line:** The **red line in Figure 1** represents the ideal trend where predictions perfectly match actual data.
#
# **Key metrics:** - **R² = 0.6755**: The model explains 67.55% of the variance in the data, demonstrating strong and stable predictive performance.
# - **Dispersion:** Most blue points cluster tightly around the red line, especially for lower DALY values, showing that the model remains highly reliable after preprocessing.
#
# **Insight:** The model successfully captures the main health trends. The high density of points near the ideal trend line in Figure 1 confirms that the machine learning approach is consistent and accurate.
#
# ---
#
# ## 2. Improved Feature Importance
#
# By using only preprocessing (Scaling) and avoiding dimensionality reduction, we can directly compare which factors drive the model's decisions compared to the FP-6 baseline.
#
#
#
# **Figure 2: Improved Feature Importance (Post-Scaling)**
#
# **What the plot shows:** - This chart ranks the input features based on their influence on the model's DALY predictions after data normalization.
#
# **Importance distribution:** 1. **Pollution Level** — ~60% weight. Remains the dominant factor, confirming that PM2.5 levels are the primary predictor of health burden.
# 2. **Disease Type** — ~39% weight. The specific type of disease significantly interacts with pollution levels to determine the outcome.
# 3. **Age Group** — <1% weight. Has minimal influence on this macro-level analysis, consistent with previous findings.
#
# **Insight:** Preprocessing confirms that environmental exposure (Pollution) is the most robust predictor. Figure 2 provides clear insight into why the model makes its predictions, highlighting pollution as the priority for public health policy.
#
# ---
#
# ## 3. Comparison of Results
#
# Finally, we compare the performance of the Baseline model from FP-6 with the Improved model utilizing StandardScaler.
#
#
#
# **Figure 3: R² Score Comparison (Baseline vs. Improved)**
#
# **Analysis:** - **Baseline (FP-6):** 0.6775
# - **Improved (Scaling):** 0.6755
#
# **Conclusion:** The results are nearly identical, with only a negligible difference in the $R^2$ score. This demonstrates that the **Random Forest** algorithm is exceptionally robust to the scale of input features. While scaling is a standard best practice in machine learning, the baseline model had already reached an optimal state. This "Improved" analysis serves to validate the stability and reliability of our initial findings from FP-6.

# %%
from improved import run_improvement_analysis, plot_validation, plot_importance, plot_comparison

model, X_test, y_test, s_base, s_imp, feat_names = run_improvement_analysis(df)

plot_validation(model, X_test, y_test)
plot_importance(model, feat_names)
plot_comparison(s_base, s_imp)
# Out:
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
