# %% [markdown]
# # Final Project FP-3:  Descriptive Statistics (Example)
#
#
# <br>
# <br>

# %% [markdown]
# ___
#
# # <span style="color:blue">Impact of Air Pollution on Public Health</span>
#
#
# ### Overview:
#
# * **Name**:  <span style="color:blue">Yaroslava Tokarieva</span>
# * **Student number**:  <span style="color:blue">B990377233</span>
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * The purpose of this Final Project is to investigate how air pollution levels are associated with health outcomes across countries and NUTS regions.
# * The key **dependent variables (DVs)** are:
#     * `Value`
#     * `Value for 100k Of Affected Population`
# * Key **independent variables (IVs)** include:
#     * `Air Pollution Average [ug/m3]`
#     * `Air Pollution Population Weighted Average [ug/m3]`
#     * `Air Pollutant`
#     * `Degree Of Urbanisation`
#     * `Population`
#     * `Affected Population`
#     * `Populated Area [km2]`
#     * `Year`
#     * `Sex`
#     * `Description Of Age Group`
#     * `Category`
#     * `Outcome`
#     * `Health Indicator`
# * This dataset contains observations across multiple European countries and NUTS regions.
#   Each row corresponds to one population group defined by region, demographic characteristics, and pollutant exposure.

# %% [markdown]
# ### Dataset source:
#
# The data come from the **“Burden of disease of air pollution (Countries & NUTS)”** dataset, provided by the
# [European Environment Agency (EEA)](https://www.eea.europa.eu/en).
#
# The data are available for download **[here](https://discomap.eea.europa.eu/App/AQViewer/index.html?fqn=Airquality_Dissem.ebd.countries_and_nuts&ScenarioDescription=Baseline%20from%20WHO%202021%20AQG&UrbanisationDegree=All%20Areas%20(incl.unclassified)&Year=2022&Sex=Total)**.
#
# Published: **10 Dec 2024** by the **European Environment Agency**.
#
# #### References:
#
# European Environment Agency (2024). *Burden of disease of air pollution (Countries & NUTS)*.

# %% [markdown]
# ___
#
# ## Descriptive Statistics

# %%
# %run descriptive.ipynb
# Out:
# <br><br><p><span style="font-size: 1.2em;"><b>Table 1</b>: Central tendency summary statistics.</span></p>
#           value  value_per_100k    year  pollution_avg  pollution_pop_avg  \
# mean    1026.02           64.47  2022.0         264.18             236.57
# median    47.00           19.00  2022.0           9.10              11.50
# mode       0.00            0.00  2022.0           8.50               8.70
#
#         population  affected_pop  area_km2
# mean     2047130.0     1445786.0   9008.95
# median    356336.0      246581.0   1347.60
# mode       33695.0       26115.0      2.00
# <br><br><p><span style="font-size: 1.2em;"><b>Table 2</b>: Dispersion summary statistics.</span></p>
#               value  value_per_100k    year  pollution_avg  pollution_pop_avg  \
# st.dev.    19884.32          152.15     0.0        1199.61            1052.87
# min            0.00            0.00  2022.0           0.10               0.30
# max      2643630.00         3728.00  2022.0       13840.40           11702.40
# range    2643630.00         3728.00     0.0       13840.30           11702.10
# 25th           7.00            3.00  2022.0           7.40               9.00
# 75th         233.00           64.00  2022.0          12.40              16.00
# IQR          226.00           61.00     0.0           5.00               7.00
#
#           population  affected_pop    area_km2
# st.dev.   20617810.0    15093311.0    90494.91
# min          17823.0        2674.0        2.00
# max      558280662.0   558271564.0  2687567.70
# range    558262839.0   558268890.0  2687565.70
# 25th        165410.0      110774.0      571.40
# 75th        965174.0      625111.0     4303.40
# IQR         799764.0      514337.0     3732.00
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_12152\3361877783.py:6
#       3 categories = ['Mortality', 'Morbidity']
#       5 for ax, cat in zip(axs, categories):
# ----> 6     data = df_filtered[df_filtered['category'] == cat]
#       8     ax.scatter(data['pollution_avg'], data['value'],
#       9                alpha=0.5, color='g', edgecolor='white', linewidth=0.3)
#      10     plot_regression_line(ax, data['pollution_avg'], data['value'],
#      11                          color='k', ls='-', lw=2)
#
# NameError: name 'df_filtered' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 get_ipython().run_line_magic('run', 'descriptive.ipynb')
#
# File ~\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:2486, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2484     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2485 with self.builtin_trap:
# -> 2486     result = fn(*args, **kwargs)
#    2488 # The code below prevents the output from being displayed
#    2489 # when using magics with decorator @output_can_be_silenced
#    2490 # when the last Python token in the expression is a ';'.
#    2491 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\miniconda3\Lib\site-packages\IPython\core\magics\execution.py:748, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     746     with preserve_keys(self.shell.user_ns, '__file__'):
#     747         self.shell.user_ns['__file__'] = filename
# --> 748         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     749     return
#     751 # Control the response to exit() calls made by the script being run
#
# File ~\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:2977, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2975 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2976 if raise_exceptions:
# -> 2977     result.raise_error()
#    2978 elif not result.success:
#    2979     break
#
# File ~\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in ExecutionResult.raise_error(self)
#     308     raise self.error_before_exec
#     309 if self.error_in_exec is not None:
# --> 310     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_12152\3361877783.py:6
#       3 categories = ['Mortality', 'Morbidity']
#       5 for ax, cat in zip(axs, categories):
# ----> 6     data = df_filtered[df_filtered['category'] == cat]
#       8     ax.scatter(data['pollution_avg'], data['value'],
#       9                alpha=0.5, color='g', edgecolor='white', linewidth=0.3)
#      10     plot_regression_line(ax, data['pollution_avg'], data['value'],
#      11                          color='k', ls='-', lw=2)
#
# NameError: name 'df_filtered' is not defined

# %%
display_central_tendency_table(num=1)
display_dispersion_table(num=2)
# Out:
# <br><br><p><span style="font-size: 1.2em;"><b>Table 1</b>: Central tendency summary statistics.</span></p>
#           value  value_per_100k    year  pollution_avg  pollution_pop_avg  \
# mean    1026.02           64.47  2022.0         264.18             236.57
# median    47.00           19.00  2022.0           9.10              11.50
# mode       0.00            0.00  2022.0           8.50               8.70
#
#         population  affected_pop  area_km2
# mean     2047130.0     1445786.0   9008.95
# median    356336.0      246581.0   1347.60
# mode       33695.0       26115.0      2.00
# <br><br><p><span style="font-size: 1.2em;"><b>Table 2</b>: Dispersion summary statistics.</span></p>
#               value  value_per_100k    year  pollution_avg  pollution_pop_avg  \
# st.dev.    19884.32          152.15     0.0        1199.61            1052.87
# min            0.00            0.00  2022.0           0.10               0.30
# max      2643630.00         3728.00  2022.0       13840.40           11702.40
# range    2643630.00         3728.00     0.0       13840.30           11702.10
# 25th           7.00            3.00  2022.0           7.40               9.00
# 75th         233.00           64.00  2022.0          12.40              16.00
# IQR          226.00           61.00     0.0           5.00               7.00
#
#           population  affected_pop    area_km2
# st.dev.   20617810.0    15093311.0    90494.91
# min          17823.0        2674.0        2.00
# max      558280662.0   558271564.0  2687567.70
# range    558262839.0   558268890.0  2687565.70
# 25th        165410.0      110774.0      571.40
# 75th        965174.0      625111.0     4303.40
# IQR         799764.0      514337.0     3732.00

# %%
plot_descriptive()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plot_descriptive()
#
# NameError: name 'plot_descriptive' is not defined
